# %%
import numpy as np
import pandas as pd
import cv2
import plotly as pintly

import matplotlib.pyplot as plt

# %%
import cv2
import numpy as np

import urllib.request
import matplotlib.pyplot as plt

resp = urllib.request.urlopen(url)
image_data = resp.read()
img = cv2.imdecode(np.frombuffer(image_data, np.uint8), cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(1199.5), np.float64(599.5), np.float64(-0.5))

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
img_crop = img[0:600, 360:830]
plt.imshow(img_crop)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(469.5), np.float64(599.5), np.float64(-0.5))

# %%
img_crop_resized = cv2.resize(img_crop, (200, 200), interpolation=cv2.INTER_AREA)
plt.imshow(img_crop_resized)
plt.axis('on')
print(img_crop_resized.shape)
# Out:
# (200, 200, 3)

# %%
blanco_y_negro = cv2.cvtColor(img_crop_resized, cv2.COLOR_RGB2GRAY)
print(blanco_y_negro.shape
# Out:
# (200, 200)

# %%
img_with_line = img_crop_resized.copy()

y = 200
thickness = 20
y = 100

h = img_with_line.shape[0]
if y >= h:
    y = h - 1
y_start = max(0, y - thickness // 2)
y_end = min(h, y_start + thickness)

img_with_line[y_start:y_end, :, :] = 0

plt.figure(figsize=(3, 3))
plt.imshow(img_with_line)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(199.5), np.float64(199.5), np.float64(-0.5))

# %%
from IPython.display import display, HTML

html = """
<h1 style="color: lightblue;">Procesamiento de imagenes</h1>
<h2>operaciones con las capas del arreglo de colores</h2>
"""
display(HTML(html))
# Out:
# <h1 style="color: lightblue;">Procesamiento de imagenes</h1>
# <h2>operaciones con las capas del arreglo de colores</h2>

# %%
url = "https://tiendalego.com.co/cdn/shop/files/77092-3_b8dae18b-a682-498a-b73a-0c89a355019b_904x904.jpg"
resp = urllib.request.urlopen(url)
image_data = resp.read()
img = cv2.imdecode(np.frombuffer(image_data, np.uint8), cv2.IMREAD_COLOR)

plt.imshow(img)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(903.5), np.float64(903.5), np.float64(-0.5))

# %%
resp = urllib.request.urlopen(url)
image_data = resp.read()
img = cv2.imdecode(np.frombuffer(image_data, np.uint8), cv2.IMREAD_COLOR)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

print(img_rgb.shape)
plt.imshow(img_rgb)
plt.axis('off')
# Out:
# (904, 904, 3)
# (np.float64(-0.5), np.float64(903.5), np.float64(903.5), np.float64(-0.5))

# %%
img_gray = cv2.cvtColor(img_rgb, cv2.COLOR_RGB2GRAY)
print(img_gray.shape)

plt.imshow(img_gray, cmap='gray')
plt.axis('off')
# Out:
# (904, 904)
# (np.float64(-0.5), np.float64(903.5), np.float64(903.5), np.float64(-0.5))

# %%
capa_azul = img_rgb[:, :, 0]
print(capa_azul.shape)
capa_azul = img_rgb[:, :, 0]
print(capa_azul.shape)
print(capa_azul)

plt.imshow(capa_azul, cmap='gray')
plt.axis('off')
plt.show()
# Out:
# (904, 904)
# (904, 904)
# [[255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  ...
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]
#  [255 255 255 ... 255 255 255]]

# %%
img_red = img_rgb.copy()
img_red[:, :, 1:] = 0

plt.imshow(img_red)
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(903.5), np.float64(903.5), np.float64(-0.5))

# %% [markdown]
# #
